# %% [markdown]
# # Using a package in a notebook
#
# This notebook demonstrates importing a package, using `dir`,
# using `help` and calling functions.

# %%
import peanut_butter_and_jelly

# %%
dir(peanut_butter_and_jelly)

# %%
peanut_butter_and_jelly.peanut_butter()

# %%
help(peanut_butter_and_jelly)

# %%
peanut_butter_and_jelly.jelly()
